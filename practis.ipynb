# %%
# @title python learning
print("Hello, World!") #This is a comment
# Out:
# Hello, World!

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
print(z,y,x)
# Out:
# awesome is Python

# %% [markdown]
# ## sep parameter

# %%
print('Ali Khan',12,12.3,True,2+2, sep='')
# Out:
# Ali Khan1212.3True4

# %%
print('Ali Khan',12,12.3,True,2+2, sep='--------')
# Out:
# Ali Khan--------12--------12.3--------True--------4

# %%
print('Ali Khan',12,12.3,True,2+2, sep='--------')
# Out:
# Ali Khan--------12--------12.3--------True--------4

# %% [markdown]
# # end parameter in print

# %%
print('Ali khan', end='\t')
print(12)
print(12.2)
print(True)
print(2+2)
# Out:
# Ali khan	12
# 12.2
# True
# 4

# %%
print('Ali khan', end='\n')
print(12)
print(12.2)
print(True)
print(2+2)
# Out:
# Ali khan
# 12
# 12.2
# True
# 4

# %%
print('Ali Khan',12,12.3,True,2+2, sep='\n')
# Out:
# Ali Khan
# 12
# 12.3
# True
# 4

# %%
print('Ali Khan',12,12.3,True,2+2, sep='\t')
# Out:
# Ali Khan	12	12.3	True	4

# %% [markdown]
# # Python Variables

# %%
#Python Variables
#Containers that stores some value
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
#print("Hello, World!")
print("Cheers, Mate!")
# Out:
# Cheers, Mate!

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %% [markdown]
# # Rules For naming Variable name
#
# - A variable can only be started with _ and alphabetic character.
# - There can be only _ between variables name
# - Keywords/special characters can not be used as varibale name i.e print, len, type etc
#
# # Data Types
# - Numbers=========>Integers(int)
# - Alphabets/Text========>String(str)
# - Decimal Numbers========>Float(float)
# - True/False, 0/1, yes/no=====>Boolean(bool)

# %%
#Variables
#Containers that stores some value
#A variable can only be started with _ and alphabetic character.
#There can be only _ between variables name
#Keywords/special characters can not be used as varibale name i.e print, len, type etc

# Data Types
#Numbers=========>Integers(int)
#Alphabets/Text========>String(str)
#Decimal Numbers========>Float(float)
#True/False, 0/1, yes/no=====>Boolean(bool)


# = is an assignment operator
a = 10 # a value 10 is assigned to a variable a(from right to left)
b = 20 # a value 10 is assigned to a variable b
c = a + b

print(c)
# Out:
# 30

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
print("Hello" + "World")
# Out:
# HelloWorld

# %%
# airthmatic operaaors
# + , - , * , / (ans flot) , // ans int , ** power or exponent,
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
d =  a * b
print(d)
# Out:
# 200

# %%
e = a / b
print(e)
# Out:
# 0.5

# %%
f = a // b
print(f)
# Out:
# 0

# %%
g= 200
h = 33
i = g // h
print(i) # 200 / 33 = 6.06 " but here answer is 6" // not take decemles "
# Out:
# 6

# %%
g = 10
h = 3
i = g // h
print(i) # 10 / 3 = 3.33 " but here answer is 3 // not take decemles "
# Out:
# 3

# %%
a = 'my name is ali khan'
b = 12
c = 12.2
d = True

# %%
type(a)
type(b)
type(c)
type(d)
# Out:
# bool

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
length = len(a)
print(length)
print(type(length))
print(type(a))
# Out:
# 19
# <class 'int'>
# <class 'str'>

# %%
id(a)
# Out:
# 132875482826432

# %%
id(b)
# Out:
# 132876502467152

# %%
id(c)
# Out:
# 132876073902224

# %% [markdown]
# # Operators

# %% [markdown]
# ## Arthimetic operators

# %%
#plus
#minus
#multiply
#divide
#exponent/power
#modulus

# %%
num1 = 10
num2 = 20
num3 = num1 + num2
print(num3)
# Out:
# 30

# %%
num3 = num1 * num2
print(num3)
# Out:
# 200

# %%
num3 = num1 / num2
print(num3)
# Out:
# 0.5

# %%
num3 = num2 / num1
print(num3)
# Out:
# 2.0

# %%
num3 = num2 // num1
print(num3)
# Out:
# 2

# %% [markdown]
# ## Operator precedence
# - BODMAS
# - PEMDAS in python

# %%
a = 20
b = 10
c = 5
d = 2
e = a * b / c + d
print(e)
# Out:
# 42.0

# %%
a*b
# Out:
# 200

# %%
a**2
# Out:
# 400

# %%
a//b
# Out:
# 2

# %%
a/b
# Out:
# 2.0

# %%
print(a+b-c)
# Out:
# 25

# %%
# / and *, left to right
# plus and minus, left to right
# power, right to left
# divide = /, //, %

# %%
a//b*c/d+c-d**c
# Out:
# -22.0

# %% [markdown]
# ## Relational operator
# - less than ===  <
# - greater than ===== >
# - less than or equal to ====== <=
# - greater than or equal to ======= >=
# - not equal to ======== !=
# - equal to ======== ==

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a != b
# Out:
# True

# %%
a == b
# Out:
# False

# %% [markdown]
# ## Logical opertors
# - and
# - or
# - not

# %%
(a<b) or (a!=b)
# Out:
# True

# %%
(a<b) and (a!=b)
# Out:
# False

# %%
not a<b
# Out:
# True

# %%
(a<b) and (a!=b) or (a>b)
# False     True       True
# Out:
# True

# %%
 (a!=b) or (a>b) and (a<b)
# True     True      False
# Out:
# True

# %% [markdown]
# ## Identry operators
# - is
# - is not
# ## Membership operators
# - in
# - not in
# ## Bitwise Operators
# - &
# - |
# - ^
# - ~
# - >>
# - <<

# %% [markdown]
# # type casting

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = 10
type (a)
# Out:
# int

# %%
a = 10.23
type(a)
# Out:
# float

# %%
a = a + 10
type(a)
# Out:
# float

# %%
a = 20
type(a)
# Out:
# int

# %%
b = float(a)
type(b)
# Out:
# float

# %%
c= 10.34
type(c)
# Out:
# float

# %%
d = int(c)
type(d)
# Out:
# int

# %%
print(c, d, sep='\n')
print(type(c))
print(type(d))
# Out:
# 10.34
# 10
# <class 'float'>
# <class 'int'>

# %%
print(c)
# Out:
# 10.34

# %%
int(c)
# Out:
# 10

# %%
float(c)
# Out:
# 10.34

# %% [markdown]
# # User Input

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
print(first_name, last_name)
# Out:
# Enter your first name: Amin
# Enter your last name: Sadruddin
# Amin  Sadruddin

# %%
print(f"Hello, {first_name} {last_name}")
# Out:
# Hello, Amin  Sadruddin

# %%
num1 = input("Enter a number: ")
num2 = input("Enter another number: ")
print(num1 + num2) # not cast
print(int(num1) + int(num2))
# Out:
# Enter a number: 11
# Enter another number: 10
# 1110
# 21

# %%
num3 = int(input("Enter a number: "))
num4 = int(input("Enter another number: "))
print(num3 + num4)
# Out:
# Enter a number: 45
# Enter another number: 45
# 90

# %% [markdown]
# - User input always takes string output

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
full_name = first_name + last_name
print(full_name)
# Out:
# Enter your first name: Amin
# Enter your last name: Sadruddin
# AminSadruddin

# %%
first_name = input("Enter your first name: ")
middle_name = input("Enter your middle name: ")
last_name = input("Enter your last name: ")
full_name = first_name + " " + middle_name + " " + last_name
print(full_name)
# Out:
# Enter your first name: Amin
# Enter your middle name: Sadruddin
# Enter your last name: Roghi
# Amin Sadruddin Roghi

# %%
print(f"Hello, {first_name} {middle_name} {last_name}")
# Out:
# Hello, Amin Sadruddin Roghi

# %%
course = str(input("Enter your course: "))
batch = int(input("Enter your batch: "))
print(f"your course name is {course} and batch numner is  {batch}")
# Out:
# Enter your course: Python
# Enter your batch: 14
# your course name is Python  and batch numner is  14

# %%
# input
{
    'karachi': 'Pakistan',
    'Chakwal': 'Pakistan',
    'Lahore': 'Pakistan',
    'Istanbul': 'Turkey',
    'Bursa': 'Turkey',
    'California': 'USA',
    'Captown': 'South Africa'
}

# output
{
    'Pakistan': ['Chakwal', 'Lahore'],
    'USA': ['California', 'Texax', 'Chicago']
}
# Out:
# {'Pakistan': ['Chakwal', 'Lahore'], 'USA': ['California', 'Texax', 'Chicago']}

# %%
cities = {
    'karachi': 'Pakistan',
    'Chakwal': 'Pakistan',
    'Lahore': 'Pakistan',
    'Istanbul': 'Turkey',
    'Bursa': 'Turkey',
    'California': 'USA',
    'Captown': 'South Africa'
}
cities
# Out:
# {'karachi': 'Pakistan',
#  'Chakwal': 'Pakistan',
#  'Lahore': 'Pakistan',
#  'Istanbul': 'Turkey',
#  'Bursa': 'Turkey',
#  'California': 'USA',
#  'Captown': 'South Africa'}

# %%
cities.values()
# Out:
# dict_values(['Pakistan', 'Pakistan', 'Pakistan', 'Turkey', 'Turkey', 'USA', 'South Africa'])

# %%
cities.keys()
# Out:
# dict_keys(['karachi', 'Chakwal', 'Lahore', 'Istanbul', 'Bursa', 'California', 'Captown'])

# %%
cities.items()
# Out:
# dict_items([('karachi', 'Pakistan'), ('Chakwal', 'Pakistan'), ('Lahore', 'Pakistan'), ('Istanbul', 'Turkey'), ('Bursa', 'Turkey'), ('California', 'USA'), ('Captown', 'South Africa')])

# %%
for i in cities.fromkeys(cities.values()):
    print(i)
    print(type(i))
# Out:
# Pakistan
# <class 'str'>
# Turkey
# <class 'str'>
# USA
# <class 'str'>
# South Africa
# <class 'str'>

# %%
d = cities.fromkeys(cities.values())
print(d)


print(d)


# car.update({"color": "White"})
# Out:
# {'Pakistan': None, 'Turkey': None, 'USA': None, 'South Africa': None}
# {'Pakistan': None, 'Turkey': None, 'USA': None, 'South Africa': None}

# %%
#
d.update{ "Pakistan" : cities.get("Pakistan")})
# Out:
#   File "<ipython-input-166-d758280d332a>", line 2
#     d.update{ "Pakistan" : cities.get("Pakistan")})
#                                                   ^
# SyntaxError: unmatched ')'

# %%
for i in d:
    d.update({(i) : cities.keys["Pakistan"]})
    print(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-162-3648f0900dd2> in <cell line: 1>()
#       1 for i in d:
# ----> 2     d.update({(i) : cities.keys["Pakistan"]})
#       3     print(d)
#       4
#       5
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
d
# Out:
# {'Pakistan': dict_keys(['karachi', 'Chakwal', 'Lahore', 'Istanbul', 'Bursa', 'California', 'Captown']),
#  'Turkey': dict_keys(['karachi', 'Chakwal', 'Lahore', 'Istanbul', 'Bursa', 'California', 'Captown']),
#  'USA': dict_keys(['karachi', 'Chakwal', 'Lahore', 'Istanbul', 'Bursa', 'California', 'Captown']),
#  'South Africa': dict_keys(['karachi', 'Chakwal', 'Lahore', 'Istanbul', 'Bursa', 'California', 'Captown'])}

# %%
d.get('Pakistan')
# Out:
# {'karachi': None,
#  'Chakwal': None,
#  'Lahore': None,
#  'Istanbul': None,
#  'Bursa': None,
#  'California': None,
#  'Captown': None}

# %%
#if cities.values() == 'Pakistan' and d.keys == "Pakistan":
 #   d.update({'Pakistan' : cities.values})
# car.update({"color": "White"})
d.update({'Pakistan' : cities.fromkeys(cities.values())})
d
d.get(cities.key)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-90b3c625ba61> in <cell line: 8>()
#       6 d
#       7
# ----> 8 d.get(cities.key)
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
for i in cities.fromkeys(cities.values()):
    print(i)
    print(type(i))
# Out:
# Pakistan
# <class 'str'>
# Turkey
# <class 'str'>
# USA
# <class 'str'>
# South Africa
# <class 'str'>

# %%
d = cities.fromkeys(cities.values())
d
# dictionary.update(iterable)
d.update({'Pakistan' : cities.keys()})
d
# Out:
# {'Pakistan': {'karachi': None,
#   'Chakwal': None,
#   'Lahore': None,
#   'Istanbul': None,
#   'Bursa': None,
#   'California': None,
#   'Captown': None},
#  'Turkey': None,
#  'USA': None,
#  'South Africa': None}

# %%
cities['karachi']
# Out:
# 'Pakistan'

# %%
cities.fromkeys(cities.keys())
# dictionary.update(iterable)
# Out:
# {'karachi': None,
#  'Chakwal': None,
#  'Lahore': None,
#  'Istanbul': None,
#  'Bursa': None,
#  'California': None,
#  'Captown': None}

# %%
for i in cities.fromkeys(cities.values()):
    if cities.values() == 'Pakistan':
        print(cities.keys())

# %%
thisdict = dict(name = "John", age = 36, country = "Norway")
print(thisdict)
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway'}
